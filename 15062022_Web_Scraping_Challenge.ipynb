# %% [markdown]
# <a href="https://colab.research.google.com/github/JCMVP92/Web-Scraping/blob/main/15062022_Web_Scraping_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Base de datos IMDB
#
# **Eres parte del equipo de Datos** 🤓 de una StartUp en su primera etapa de inversión que se dedica a la venta de articulos colección de las peliculas 🎬 y series de TV 📺 que aparecen en los **ranking top** 🏆 de U.S.A.
#
# Por ahora **la API** 🤖 que utilizan para extraer los datos de las peliculas top de IMDb **continua caída** por [las fallas de AWS](https://www.theguardian.com/technology/2021/dec/07/amazon-web-services-outage-hits-sites-and-apps-such-as-imdb-and-tinder) 😓 del 7 de Diciembre del 2021, por lo que **se requiere que se establezca una alternativa**.
#
# **Tú como lider** del equipo de interns **has definido el plan de obtener** la lista de las peliculas target **a partir del Scrapping** 🦾 de las paginas de los top del sitio web **de IMDb** 🎬.

# %% [markdown]
# # Instrucciones

# %% [markdown]
# Deberás compartirle al equipo de producción las listas de peliculas y shows de las siguientes categorías generando un archivo CSV:
#
# - [Top 10 Most Popular Movies](https://www.imdb.com/chart/moviemeter/?ref_=nv_mv_mpm)
# - [Top 10 de peliculas del 2021 al 2018](https://www.imdb.com/chart/top?sort=us,desc&mode=simple&page=1)
# - [Top 10 de TV Shows](https://www.imdb.com/chart/toptv/?sort=us,desc&mode=simple&page=1)

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
r = requests.get('https://www.imdb.com/chart/moviemeter/?ref_=nv_mv_mpm')
print(len(r.text))
# Out:
# 357424

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.text)

# %%
soup.find_all('a')
# Out:
# [<a href="/?ref_=nv_home"><svg class="ipc-logo drawer-logo" height="56" version="1.1" viewbox="0 0 64 32" width="98" xmlns="http://www.w3.org/2000/svg"><g fill="#F5C518"><rect height="100%" rx="4" width="100%" x="0" y="0"></rect></g><g fill="#000000" fill-rule="nonzero" transform="translate(8.000000, 7.000000)"><polygon points="0 18 5 18 5 0 0 0"></polygon><path d="M15.6725178,0 L14.5534833,8.40846934 L13.8582008,3.83502426 C13.65661,2.37009263 13.4632474,1.09175121 13.278113,0 L7,0 L7,18 L11.2416347,18 L11.2580911,6.11380679 L13.0436094,18 L16.0633571,18 L17.7583653,5.8517865 L17.7707076,18 L22,18 L22,0 L15.6725178,0 Z"></path><path d="M24,18 L24,0 L31.8045586,0 C33.5693522,0 35,1.41994415 35,3.17660424 L35,14.8233958 C35,16.5777858 33.5716617,18 31.8045586,18 L24,18 Z M29.8322479,3.2395236 C29.6339219,3.13233348 29.2545158,3.08072342 28.7026524,3.08072342 L28.7026524,14.8914865 C29.4312846,14.8914865 29.8796736,14.7604764 30.0478195,14.4865461 C30.2159654,14.2165858 30.3021941,13.4
# ...

# %%
##Most Popular Movies

# %%
for link in soup.find_all('img'):
    print(link.get('alt'))
# Out:
# Top Gun: Maverick
# Jurassic World: Dominion
# Top Gun
# Hustle
# Interceptor
# Everything Everywhere All at Once
# Fantastic Beasts: The Secrets of Dumbledore
# Black Adam
# The Northman
# The Unbearable Weight of Massive Talent
# Bullet Train
# Doctor Strange in the Multiverse of Madness
# Elvis
# Thor: Love and Thunder
# Crimes of the Future
# The Batman
# Morbius
# Last Seen Alive
# Jurassic Park
# Fire Island
# Skull
# X
# The Lost City
# What Is a Woman?
# Vikram
# Chip 'n Dale: Rescue Rangers
# Nope
# Jurassic World: Fallen Kingdom
# Jurassic World
# The Godfather
# Men
# Pinocchio
# The Munsters
# Lightyear
# The Lady of Heaven
# The Black Phone
# Downton Abbey: A New Era
# Sonic the Hedgehog 2
# Major
# Senior Year
# Spider-Man: No Way Home
# RRR
# Winnie-The-Pooh: Blood and Honey
# Uncharted
# Death on the Nile
# Fantastic Beasts: The Crimes of Grindelwald
# Ghostbusters: Afterlife
# No Time to Die
# Father Stu
# The Bad Guys
# Ambulance
# Old
# ...

# %%
#Top 10 de peliculas del 2021 al 2018

# %%
c = requests.get('https://www.imdb.com/chart/top?sort=us,desc&mode=simple&page=1')
print(len(c.text))
# Out:
# 595517

# %%
soup = BeautifulSoup(c.text)
soup.find_all('a')
# Out:
# [<a href="/?ref_=nv_home"><svg class="ipc-logo drawer-logo" height="56" version="1.1" viewbox="0 0 64 32" width="98" xmlns="http://www.w3.org/2000/svg"><g fill="#F5C518"><rect height="100%" rx="4" width="100%" x="0" y="0"></rect></g><g fill="#000000" fill-rule="nonzero" transform="translate(8.000000, 7.000000)"><polygon points="0 18 5 18 5 0 0 0"></polygon><path d="M15.6725178,0 L14.5534833,8.40846934 L13.8582008,3.83502426 C13.65661,2.37009263 13.4632474,1.09175121 13.278113,0 L7,0 L7,18 L11.2416347,18 L11.2580911,6.11380679 L13.0436094,18 L16.0633571,18 L17.7583653,5.8517865 L17.7707076,18 L22,18 L22,0 L15.6725178,0 Z"></path><path d="M24,18 L24,0 L31.8045586,0 C33.5693522,0 35,1.41994415 35,3.17660424 L35,14.8233958 C35,16.5777858 33.5716617,18 31.8045586,18 L24,18 Z M29.8322479,3.2395236 C29.6339219,3.13233348 29.2545158,3.08072342 28.7026524,3.08072342 L28.7026524,14.8914865 C29.4312846,14.8914865 29.8796736,14.7604764 30.0478195,14.4865461 C30.2159654,14.2165858 30.3021941,13.4
# ...

# %%
for link in soup.find_all('img'):
    print(link.get('alt'))
# Out:
# Top Gun: Maverick
# Everything Everywhere All at Once
# Spider-Man: No Way Home
# Jai Bhim
# Hamilton
# The Father
# 1917
# Klaus
# Joker
# Ford v Ferrari
# Parasite
# Avengers: Endgame
# Spider-Man: Into the Spider-Verse
# Green Book
# Capernaum
# Avengers: Infinity War
# Coco
# Three Billboards Outside Ebbing, Missouri
# Logan
# Dangal
# Hacksaw Ridge
# Your Name.
# The Handmaiden
# Room
# Spotlight
# Inside Out
# Mad Max: Fury Road
# Interstellar
# Gone Girl
# Wild Tales
# The Grand Budapest Hotel
# Whiplash
# The Wolf of Wall Street
# Rush
# Prisoners
# 12 Years a Slave
# Django Unchained
# The Dark Knight Rises
# The Hunt
# The Intouchables
# Warrior
# The Help
# Harry Potter and the Deathly Hallows: Part 2
# A Separation
# Incendies
# Inception
# Toy Story 3
# How to Train Your Dragon
# Shutter Island
# 3 Idiots
# The Secret in Their Eyes
# Hachi: A Dog's Tale
# Inglourious Basterds
# Up
# Mary and Max
# Gran Torino
# The Dark Knight
# WALL·E
# Like Stars on Earth
# ...

# %%
d = requests.get('https://www.imdb.com/chart/toptv/?sort=us,desc&mode=simple&page=1')
print(len(d.text))
# Out:
# 590952

# %%
d.text
# Out:
# '\n\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n         \n\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    \n    \n    \n\n    \n    \n    \n\n            <style>\n                body#styleguide-v2 {\n                    background: no-repeat fixed center top #000;\n                }\n            </style>\n\n\n\n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>IMDb Top 250 TV - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>\n<script>\n    if (typeof uet == \'f
# ...

# %%
soup = BeautifulSoup(d.text)

# %%
soup.find_all('a')
# Out:
# [<a href="/?ref_=nv_home"><svg class="ipc-logo drawer-logo" height="56" version="1.1" viewbox="0 0 64 32" width="98" xmlns="http://www.w3.org/2000/svg"><g fill="#F5C518"><rect height="100%" rx="4" width="100%" x="0" y="0"></rect></g><g fill="#000000" fill-rule="nonzero" transform="translate(8.000000, 7.000000)"><polygon points="0 18 5 18 5 0 0 0"></polygon><path d="M15.6725178,0 L14.5534833,8.40846934 L13.8582008,3.83502426 C13.65661,2.37009263 13.4632474,1.09175121 13.278113,0 L7,0 L7,18 L11.2416347,18 L11.2580911,6.11380679 L13.0436094,18 L16.0633571,18 L17.7583653,5.8517865 L17.7707076,18 L22,18 L22,0 L15.6725178,0 Z"></path><path d="M24,18 L24,0 L31.8045586,0 C33.5693522,0 35,1.41994415 35,3.17660424 L35,14.8233958 C35,16.5777858 33.5716617,18 31.8045586,18 L24,18 Z M29.8322479,3.2395236 C29.6339219,3.13233348 29.2545158,3.08072342 28.7026524,3.08072342 L28.7026524,14.8914865 C29.4312846,14.8914865 29.8796736,14.7604764 30.0478195,14.4865461 C30.2159654,14.2165858 30.3021941,13.4
# ...

# %%
for link in soup.find_all('img'):
    print(link.get('alt'))
# Out:
# Bosch: Legacy
# Heartstopper
# Severance
# 1883
# The Beatles: Get Back
# Arcane
# Dopesick
# Clarkson's Farm
# Mare of Easttown
# Aspirants
# Invincible
# It's a Sin
# As If
# The Queen's Gambit
# Scam 1992: The Harshad Mehta Story
# Jujutsu Kaisen
# Ted Lasso
# The Last Dance
# Panchayat
# Crash Landing on You
# Harley Quinn
# The Mandalorian
# Primal
# The Family Man
# The Boys
# Vinland Saga
# Gullak
# When They See Us
# Chernobyl
# Kota Factory
# Demon Slayer: Kimetsu no Yaiba
# Our Planet
# What We Do in the Shadows
# Love, Death & Robots
# Formula 1: Drive to Survive
# The Haunting of Hill House
# Mr Inbetween
# My Brilliant Friend
# Yeh Meri Family
# Yellowstone
# Pose
# Cobra Kai
# Succession
# Persona
# Queer Eye
# The Punisher
# Blue Planet II
# Mindhunter
# The Vietnam War
# Dark
# Black Sun
# Ozark
# The Defiant Ones
# Anne with an E
# The Marvelous Mrs. Maisel
# Twin Peaks
# Big Little Lies
# The Grand Tour
# Planet Earth II
# Westworld
# This Is Us
# Atlanta
# Fleabag
# ...
